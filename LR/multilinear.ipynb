# %%
import pandas as pd
from sklearn import linear_model

# %%
df=pd.read_csv('insurance2.csv')

# %%
df
# Out:
#    age  height  weight  premium
# 0   25  162.56      70    18000
# 1   30  172.72      95    38000
# 2   35  167.64      78    38000
# 3   40     NaN     110    60000
# 4   45  157.48      85    70000

# %%
 mean_height=df.height.mean()

# %%
df.height=df.height.fillna(mean_height)

# %%
df
# Out:
#    age  height  weight  premium
# 0   25  162.56      70    18000
# 1   30  172.72      95    38000
# 2   35  167.64      78    38000
# 3   40  165.10     110    60000
# 4   45  157.48      85    70000

# %%
reg=linear_model.LinearRegression()

# %%
reg.fit(df[['age','height','weight']],df['premium'])
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([2150.26052416, -248.45851574,  312.65291961])

# %%
reg.intercept_
# Out:
# -16827.013154824897

# %%
reg.predict([[27,167.56,60]])
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([18357.48727691])

# %%
2150.26052416*27+-248.45851574*167.56+312.65291961*60+-16827.013154824897
# Out:
# 18357.487276700704

# %%
reg.predict([[60,165.10,80]])
# Out:
# C:\Users\hp\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([96180.35091498])

# %%
2150.26052416*60+-248.45851574*165.10+312.65291961*80+-16827.013154824897
# Out:
# 96180.3509149011
